# %%
from graphics import *
import math
pi = math.pi

win = GraphWin("Sign window", 200,400)
# Time to create shapes
Box_0 = Rectangle(Point(64,85), Point(136, 245))
Box_1 = Rectangle(Point(70,100), Point(130, 110))
Box_2 = Rectangle(Point(70,112), Point(130, 122))
Box_3 = Rectangle(Point(70,124), Point(130, 134))
Box_4 = Rectangle(Point(70,136), Point(130, 146))
Box_5 = Rectangle(Point(70,148), Point(130, 158))
Box_6 = Rectangle(Point(70,160), Point(130, 170))
Box_7 = Rectangle(Point(70,172), Point(130, 182))
Box_8 = Rectangle(Point(70,184), Point(130, 194))
Box_9 = Rectangle(Point(70,196), Point(130, 206))
Box_10 = Rectangle(Point(70,208), Point(130, 218))
Box_11 = Rectangle(Point(70,220), Point(130, 230))
Round_1 = Circle(Point(100,300),30)
Round_2 = Circle(Point(110,316),6)
# Time to fill color in the shapes
Box_0.setFill(color_rgb(0,0,0))
Box_1.setFill(color_rgb(146,43,33))
Box_2.setFill(color_rgb(204,0,0))
Box_3.setFill(color_rgb(203,67,53))
Box_4.setFill(color_rgb(229,115,115))
Box_5.setFill(color_rgb(255,205,210))
Box_6.setFill(color_rgb(250,250,255))
Box_7.setFill(color_rgb(225, 245, 254))
Box_8.setFill(color_rgb(129, 212, 250))
Box_9.setFill(color_rgb(41, 182, 246))
Box_10.setFill(color_rgb(0, 102, 255))
Box_11.setFill(color_rgb(0, 0, 102 ))
Round_1.setOutline('blue')
#Time to draw all the shapes
Box_0.draw(win)
Box_1.draw(win)
Box_2.draw(win)
Box_3.draw(win)
Box_4.draw(win)
Box_5.draw(win)
Box_6.draw(win)
Box_7.draw(win)
Box_8.draw(win)
Box_9.draw(win)
Box_10.draw(win)
Box_11.draw(win)
Round_1.draw(win)
Round_2.draw(win)

# If you want spikes around circle, but these would not be much that straighter
# and would decrese in length on increasing heaight
# if want to see how this looks , uncomment the following lines
#def PointsInCircum(r,n=100):
# return [(math.cos(2*pi/n*x)*r,math.sin(2*pi/n*x)*r) for x in range(0,n+1)]
#P = PointsInCircum(32,n=50)
#Q = PointsInCircum(37,n=50)
#i=0
#while(i<50):
# p1 = Point(P[i][0] + 100 ,P[i][1] + 300)
# p2 = Point(Q[i][0] + 100, P[i][1] + 300)
# Line(p1,p2).draw(win)
# i += 1
